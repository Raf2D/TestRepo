# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1 style="color:red">Data Science Tools and Ecosystem</h1>

# %% [markdown]
# ## In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives**
# * Create a Jupyter Notebook
# * Using markdown and code cells
# * Using comments in python
# * List popular languages for Data Science
# * List commonly used libraries used by Data Scientists
# * Show simple mathematical operations in python
# * Share notebook through GitHub

# %% [markdown]
# ### Some of the popular languages thet Data Scientists use are:

# %% [markdown]
# 1. Python
# 2. R
# 3. SQL
# 4. Scala
# 5. java
# 6. C++

# %% [markdown]
# ### Some of the commonly used libraries used by Data Scientists include:

# %% [markdown]
# #### - Data manipulation and analysis
# 1. Pandas (Python) - handling tabular datasets, data frames, cleaning and trasforming data.
# 2. Numpy (Python) - fast numerical and matrix computations.

# %% [markdown]
# #### -Visualization
# 1. Matplotlib (Python) - customizable static plots.
# 2. ggplot2 (R) - it allows you to build plots in a logical and layered manner.

# %% [markdown]
# #### -Machine Learning
# 1. Scikit-Learn (Python) - classification, regression, clustering, dimensionality reduction.
# 2. Tensorflow (Python) - deep learning, neural networks, complex models.

# %% [markdown]
# |Data Science Tools|
# |-------------------|
# |jupyter notebook|
# |RStudio IDE     |
# |Visual studio code|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
#this a simple arithmetic expression to multiply then add integers
(3*4)+5
# Out:
# 17

# %%
#this will convert 200 minutes to hours by diving by 60
import math
a = (200/60)
minutes,hours  = math.modf(a)
print('200 minutes in hours: ', round(a,2))
minutes = minutes*60
print('200 minutes in hours e minutes: ',round(hours),'Hours and ',round(minutes),'Minutes.')
# Out:
# 200 minutes in hours:  3.33
# 200 minutes in hours e minutes:  3 Hours and  20 Minutes.

# %% [markdown]
# <h2 style="color:blue;">Author</h2>
# Raffaele Caputi
